# %%
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2, 10)
y = np.sin(np.pi*x)
ax = plt.figure().add_subplot(111)
#ax.plot(x, y, marker = '*')
ax.scatter(x, y, marker = '*')
# Out:
# <img src="data:image/png;base64,...">

# %%
def get_y(Fx, Px, Py):
    y = [0 for j in range(Fx.shape[0])]
    for j in range(Fx.shape[0]):
        for i in range(Px.shape[0]):
            condition1 = Px[i] >= Fx[j]
            condition2 = Fx[j] >= Px[i-1]
            if np.logical_and(condition1,condition2):
                y[j] = Py[i-1] + (Py[i]-Py[i-1])/(Px[i]-Px[i-1])*(Fx[j]-Px[i-1])
    return y
Px = np.linspace(0, 2, 10)
Fx = np.linspace(0, 2, 100)
Py = np.sin(np.pi*Px)
print Fx 
np.random.shuffle(Fx)
print Fx
#print get_y(Fx, Px, Py)
x = np.linspace(0, 2, 10)
y = np.sin(np.pi*x)
ax = plt.figure().add_subplot(111)
ax.plot(x, y, marker = '*')
ax.plot(Fx, get_y(Fx,Px,Py), marker = '*', linestyle = 'none')
# Out:
# [ 0.          0.02020202  0.04040404  0.06060606  0.08080808  0.1010101
#   0.12121212  0.14141414  0.16161616  0.18181818  0.2020202   0.22222222
#   0.24242424  0.26262626  0.28282828  0.3030303   0.32323232  0.34343434
#   0.36363636  0.38383838  0.4040404   0.42424242  0.44444444  0.46464646
#   0.48484848  0.50505051  0.52525253  0.54545455  0.56565657  0.58585859
#   0.60606061  0.62626263  0.64646465  0.66666667  0.68686869  0.70707071
#   0.72727273  0.74747475  0.76767677  0.78787879  0.80808081  0.82828283
#   0.84848485  0.86868687  0.88888889  0.90909091  0.92929293  0.94949495
#   0.96969697  0.98989899  1.01010101  1.03030303  1.05050505  1.07070707
#   1.09090909  1.11111111  1.13131313  1.15151515  1.17171717  1.19191919
#   1.21212121  1.23232323  1.25252525  1.27272727  1.29292929  1.31313131
#   1.33333333  1.35353535  1.37373737  1.39393939  1.41414141  1.43434343
#   1.45454545  1.47474747  1.49494949  1.51515152  1.53535354  1.55555556
# ...

# %%
input
    t - array
    y - array
    x - "real number"
output
    y - "real number"
algorithm
    for i in tindicies
        if x < t[i]
            i_0 = i
            break
        x0 = t[i0-1]
        x1 = t[i0]
        y0 = y[i0-1]
        y1 = y[i0]
        y = linear formua
        return y

# %%
t = np.linspace(0, 2, 10)
x = np.sin(np.pi*t)

def interp(tt):
    for i in range(t.shape[0]):
        if tt < t[i]:
            i0 = i
            break
        else:
            i0 = i
    y = x[i0] + ((x[i0]-x[i0-1])/(t[i0]-t[i0-1]))* (tt-t[i0])
    return y

tfine = np.linspace(0,1,50)
yfine = []
for var in tfine:
    yfine.append(interp(var))
    
ax = plt.figure().add_subplot(111)
ax.plot(t, x)
ax.plot(tfine, yfine, marker= '+', linestyle = 'none')
# Out:
# <img src="data:image/png;base64,...">
